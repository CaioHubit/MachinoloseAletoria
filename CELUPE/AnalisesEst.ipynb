# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Preparando o Dataframe
df = pd.read_csv('DADOS CCNF.txt', delimiter='\t', decimal=',')

#display(df.to_string())
#df.astype({"Transmitancia":"int32"})
df["Transmitancia"][0]
# Out:
# 78.721

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Suponha que você tenha um DataFrame chamado 'df' com as colunas "Name" e "Transmitancia"
# Certifique-se de que você importou os dados corretamente para o DataFrame.

# Calcular o desvio padrão da coluna "Transmitancia"
desvio_padrao = df['Transmitancia'].std()

# Plotar o gráfico de caixa (boxplot) com os dados da coluna "Transmitancia"
plt.figure(figsize=(10, 6))
plt.boxplot(df['Transmitancia'])
plt.title("Diagrama de Caixa da Transmitância")
plt.ylabel("Transmitância")
plt.xticks([1], ["Dados"])
plt.grid(True)

# Adicionar o desvio padrão médio como texto no gráfico
plt.text(1.1, desvio_padrao, f'Desvio Padrão: {desvio_padrao:.2f}', fontsize=12)

# Adicionar os nomes das medidas na coluna "Name"
plt.xticks([1], [", ".join(df['Name'])])

# Mostrar o gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Eixo x
x = np.arange(len(Name))

# Cria a figura e os eixos
fig, ax = plt.subplots(figsize=(12, 6))

# Plota o grid atrás das barras
ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

# Substitua 'Transmitancia' pela coluna desejada
valores_transmitancia = df['Transmitancia']

# Plota as barras de média
cor_barras = cores_barras[i]
barra_media = ax.bar(x, valores_transmitancia, largura_barra, label='Transmitância', zorder=2, color=cor_barras)

# Plota as linhas de desvio padrão
lines = {'linestyle': 'None'}
plt.rc('lines', **lines)
posicao_desvios = x + largura_barra / 2**10
ax.errorbar(posicao_desvios, valores_transmitancia, yerr=desvios, marker='o', capsize=10, markersize=6, fmt='', color='black', label='Desvio Padrão', zorder=3)

# Configurações adicionais
ax.set_xlabel('Dosagem de floculante (mg)')
ax.set_ylabel('Transmitância(%)')
ax.set_title('Média e Desvio Padrão')
ax.set_xticks(x)
ax.set_xticklabels(nomes)
ax.legend()

# Salvar o gráfico em um arquivo PNG
plt.tight_layout()
plt.savefig(f'grafico_{i + 1}.png')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CAIO22~1\AppData\Local\Temp/ipykernel_20084/4256297436.py in <module>
#       3
#       4 # Eixo x
# ----> 5 x = np.arange(len(nomes))
#       6
#       7 # Cria a figura e os eixos
#
# NameError: name 'nomes' is not defined
